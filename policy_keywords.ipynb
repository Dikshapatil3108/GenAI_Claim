# %% [markdown]
# <a href="https://colab.research.google.com/github/Dikshapatil3108/GenAI_Claim/blob/main/policy_keywords.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install google-generativeai

# %%
import google.generativeai as genai
import os

# Set your Gemini API Key
os.environ["GOOGLE_API_KEY"] = "AIzaSyA8jvipHq3awtK-Uh2cB1GGPonaUj7z1tc"
genai.configure(api_key=os.environ["GOOGLE_API_KEY"])

# %%
# !pip install -U langchain-community
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 46.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.2/45.2 kB 3.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 3.4 MB/s eta 0:00:00
# ...

# %%
model = genai.GenerativeModel("gemini-pro")  # Use gemini-pro or other model name

# %%
# !pip install pypdf
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.2/313.2 kB 8.0 MB/s eta 0:00:00
# ...

# %%
# !pip install PyMuPDF
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.1/24.1 MB 20.3 MB/s eta 0:00:00
# ...

# %%
api_key = os.getenv("GEMINI_API_KEY")
genai.configure(api_key=api_key)

# %%
import os
import fitz  # PyMuPDF
import google.generativeai as genai
from google.colab import userdata # Import userdata

# === STEP 1: Set up your Gemini API Key securely ===
# os.environ["GOOGLE_API_KEY"] = "AIzaSyD2eTdgrEiLn6XKgPwfOOaB0uLX7OJVFd0".strip()  # Replace with your actual API key
# genai.configure(api_key=os.getenv("GOOGLE_API_KEY").strip())

# Get the API key from Colab secrets
GOOGLE_API_KEY=userdata.get('GOOGLE_API_KEY')
genai.configure(api_key=GOOGLE_API_KEY)


# === STEP 2: Function to extract text from PDF ===
def extract_text_from_pdf(pdf_path):
    doc = fitz.open(pdf_path)
    full_text = ""
    for page in doc:
        full_text += page.get_text()
    doc.close()
    return full_text

# === STEP 3: Extract structured policy data using Gemini ===
def extract_policy_details_from_pdf(pdf_path):
    pdf_text = extract_text_from_pdf(pdf_path)

    prompt = f"""
You are an AI assistant working for a health insurance company.

From the text below, extract the following **policy-related details**:
- Policy Name
- Policy Number (if available)
- Type of Plan (e.g., Individual, Family, Corporate, Youth)
- Eligibility Criteria (age, conditions, etc.)
- Sum Insured options
- Premium details
- Coverage benefits (brief list)
- Major exclusions
- Policy term/duration
- Renewal terms
- Waiting period (if mentioned)

Return the result in this structured format:
Policy Name:
Policy Number:
Plan Type:
Eligibility Criteria:
Sum Insured:
Premium Details:
Coverage Benefits:
Exclusions:
Policy Term:
Renewal Terms:
Waiting Period:

Text to analyze:
\"\"\"{pdf_text}\"\"\"
"""

    model = genai.GenerativeModel("gemini-2.5-flash-preview-05-20")
    response = model.generate_content(prompt)
    return response.text

# === STEP 4: Run the extraction ===
pdf_path ="/content/Revised_Reliance_Health_Gain_Policy_Wordings.pdf"  # Replace with your actual PDF path
result = extract_policy_details_from_pdf(pdf_path)

# === STEP 5: Display result ===
print("=== Extracted Policy Details ===")
print(result)
# Out:
# === Extracted Policy Details ===
# Here are the policy-related details extracted from the provided text:
#
# **Policy Name:** Reliance Health Gain Policy
# **Policy Number:** RELHLIP22229V032122 (UIN)
# **Plan Type:** Individual and Family Floater options available, across three plans: Plus, Power, and Prime.
# **Eligibility Criteria:**
# *   **Children:** 3 months to 25 years (biological or legally adopted), must be financially dependent. Financially independent children above 18 years are ineligible for subsequent renewals in a family plan.
# *   **Newborns:** Covered from 90 days mid-term upon marriage.
# *   **Senior Citizens:** Persons aged 60 years and above are covered, subject to Co-Payment conditions.
# **Sum Insured:**
# *   **New Business Base Sum Insured (in Lakhs INR):**
#     *   Plus: 3, 5
#     *   Power: 10, 15, 20
#     *   Prime: 25, 30, 50, 100
# *   **Renewal Business/Call Option Base Sum Insured (in Lakhs INR):**
#     *   Plus: 3, 5, 6, 9
# ...

# %%
import os
import fitz  # PyMuPDF
import google.generativeai as genai
from google.colab import userdata # Import userdata

# === STEP 1: Set up your Gemini API Key securely ===
# os.environ["GOOGLE_API_KEY"] = "AIzaSyD2eTdgrEiLn6XKgPwfOOaB0uLX7OJVFd0".strip()  # Replace with your actual API key
# genai.configure(api_key=os.getenv("GOOGLE_API_KEY").strip())

# Get the API key from Colab secrets
GOOGLE_API_KEY=userdata.get('GOOGLE_API_KEY')
genai.configure(api_key=GOOGLE_API_KEY)


# === STEP 2: Function to extract text from PDF ===
def extract_text_from_pdf(pdf_path):
    doc = fitz.open(pdf_path)
    full_text = ""
    for page in doc:
        full_text += page.get_text()
    doc.close()
    return full_text

# === STEP 3: Extract structured policy data using Gemini ===
def extract_policy_details_from_pdf(pdf_path):
    pdf_text = extract_text_from_pdf(pdf_path)

    prompt = f"""
You are an AI assistant working for a health insurance company.

From the text below, extract the following **policy-related details**:
- Policy Name
- Policy Number (if available)
- Type of Plan (e.g., Individual, Family, Corporate, Youth)
- Eligibility Criteria (age, conditions, etc.)
- Sum Insured options
- Premium details
- Coverage benefits (brief list)
- Major exclusions
- Policy term/duration
- Renewal terms
- Waiting period (if mentioned)

Return the result in this structured format:
Policy Name:
Policy Number:
Plan Type:
Eligibility Criteria:
Sum Insured:
Premium Details:
Coverage Benefits:
Exclusions:
Policy Term:
Renewal Terms:
Waiting Period:

Text to analyze:
\"\"\"{pdf_text}\"\"\"
"""

    model = genai.GenerativeModel("gemini-2.5-flash-preview-05-20")
    response = model.generate_content(prompt)
    return response.text

# === STEP 4: Run the extraction ===
pdf_path = "/content/icihlip23144v072223-icici-lombard-complete-health-insurance.pdf"  # Replace with your actual PDF path
result = extract_policy_details_from_pdf(pdf_path)

# === STEP 5: Display result ===
print("=== Extracted Policy Details ===")
print(result)
# Out:
# === Extracted Policy Details ===
# Here are the policy-related details extracted from the text:
#
# **Policy Name:** ICICI LOMBARD COMPLETE HEALTH INSURANCE
# **Policy Number:** UIN : ICIHLIP23144V072223
# **Plan Type:** Individual and Family Floater options available.
# **Eligibility Criteria:**
# *   **General:** Insured Person(s) as named in the Policy Schedule.
# *   **Specific Covers:**
#     *   Health Coach / Preventive Health Check-up: Insured Persons aged 21 and above.
#     *   BeFit Cover / Worldwide Cover: Insured Persons up to the age of 65 years.
#     *   Newborn Baby Cover: Baby aged up to 90 days.
#     *   Worldwide Cover also requires residency in India within geographical boundaries during policy issuance.
# ...

# %%
import os
import fitz  # PyMuPDF
import google.generativeai as genai
from google.colab import userdata # Import userdata

# === STEP 1: Set up your Gemini API Key securely ===
# os.environ["GOOGLE_API_KEY"] = "AIzaSyD2eTdgrEiLn6XKgPwfOOaB0uLX7OJVFd0".strip()  # Replace with your actual API key
# genai.configure(api_key=os.getenv("GOOGLE_API_KEY").strip())

# Get the API key from Colab secrets
GOOGLE_API_KEY=userdata.get('GOOGLE_API_KEY')
genai.configure(api_key=GOOGLE_API_KEY)


# === STEP 2: Function to extract text from PDF ===
def extract_text_from_pdf(pdf_path):
    doc = fitz.open(pdf_path)
    full_text = ""
    for page in doc:
        full_text += page.get_text()
    doc.close()
    return full_text

# === STEP 3: Extract structured policy data using Gemini ===
def extract_policy_details_from_pdf(pdf_path):
    pdf_text = extract_text_from_pdf(pdf_path)

    prompt = f"""
You are an AI assistant working for a health insurance company.

From the text below, extract the following **policy-related details**:
- Policy Name
- Policy Number (if available)
- Type of Plan (e.g., Individual, Family, Corporate, Youth)
- Eligibility Criteria (age, conditions, etc.)
- Sum Insured options
- Premium details
- Coverage benefits (brief list)
- Major exclusions
- Policy term/duration
- Renewal terms
- Waiting period (if mentioned)

Return the result in this structured format:
Policy Name:
Policy Number:
Plan Type:
Eligibility Criteria:
Sum Insured:
Premium Details:
Coverage Benefits:
Exclusions:
Policy Term:
Renewal Terms:
Waiting Period:

Text to analyze:
\"\"\"{pdf_text}\"\"\"
"""

    model = genai.GenerativeModel("gemini-2.5-flash-preview-05-20")
    response = model.generate_content(prompt)
    return response.text

# === STEP 4: Run the extraction ===
pdf_path = "/content/care-plus----health-insurance-plan-for-youth-brochure.pdf"  # Replace with your actual PDF path
result = extract_policy_details_from_pdf(pdf_path)

# === STEP 5: Display result ===
print("=== Extracted Policy Details ===")
print(result)
# Out:
# === Extracted Policy Details ===
# Policy Name: Care Plus - Complete Health Insurance Plan
# Policy Number: UIN:CHIHLIP22047V012122 (Product UIN)
# Plan Type: Individual and Family Floater
# Eligibility Criteria:
# *   **Minimum Entry Age:**
#     *   Individual: 5 years
#     *   Floater: 91 days (with at least 1 member aged 18 years or above)
# *   **Maximum Entry Age:**
#     *   Adult: Lifelong
#     *   Child: 24 years
# *   **Exit Age:**
#     *   Adult: Lifelong
#     *   Child: 25 years
# *   **Specific Benefits Eligibility:**
#     *   Earn & Burn: Member aged 18 years or above.
#     *   Maternity & New Born Cover: Only under Floater combinations of 2A & 2A1C for insured persons aged 18 years or above.
# Sum Insured: 3 Lakhs / 5 Lakhs / 7 Lakhs / 10 Lakhs / 25 Lakhs (on annual basis)
# Premium Details:
# *   15% discount available with 'Smart Select' option (applicable on base benefit premium and optional Maternity and New Born cover premium).
# Coverage Benefits:
# ...

# %%
import os
import fitz  # PyMuPDF
import google.generativeai as genai
from google.colab import userdata # Import userdata

# === STEP 1: Set up your Gemini API Key securely ===
# os.environ["GOOGLE_API_KEY"] = "AIzaSyD2eTdgrEiLn6XKgPwfOOaB0uLX7OJVFd0".strip()  # Replace with your actual API key
# genai.configure(api_key=os.getenv("GOOGLE_API_KEY").strip())

# Get the API key from Colab secrets
GOOGLE_API_KEY=userdata.get('GOOGLE_API_KEY')
genai.configure(api_key=GOOGLE_API_KEY)


# === STEP 2: Function to extract text from PDF ===
def extract_text_from_pdf(pdf_path):
    doc = fitz.open(pdf_path)
    full_text = ""
    for page in doc:
        full_text += page.get_text()
    doc.close()
    return full_text

# === STEP 3: Extract structured policy data using Gemini ===
def extract_policy_details_from_pdf(pdf_path):
    pdf_text = extract_text_from_pdf(pdf_path)

    prompt = f"""
You are an AI assistant working for a health insurance company.

From the text below, extract the following **policy-related details**:
- Policy Name
- Policy Number (if available)
- Type of Plan (e.g., Individual, Family, Corporate, Youth)
- Eligibility Criteria (age, conditions, etc.)
- Sum Insured options
- Premium details
- Coverage benefits (brief list)
- Major exclusions
- Policy term/duration
- Renewal terms
- Waiting period (if mentioned)

Return the result in this structured format:
Policy Name:
Policy Number:
Plan Type:
Eligibility Criteria:
Sum Insured:
Premium Details:
Coverage Benefits:
Exclusions:
Policy Term:
Renewal Terms:
Waiting Period:

Text to analyze:
\"\"\"{pdf_text}\"\"\"
"""

    model = genai.GenerativeModel("gemini-2.5-flash-preview-05-20")
    response = model.generate_content(prompt)
    return response.text

# === STEP 4: Run the extraction ===
pdf_path = "/content/Family_Plus_Policy_Document.pdf"  # Replace with your actual PDF path
result = extract_policy_details_from_pdf(pdf_path)

# === STEP 5: Display result ===
print("=== Extracted Policy Details ===")
print(result)
# Out:
# === Extracted Policy Details ===
# Here are the policy-related details extracted from the provided text:
#
# **Policy Name:** Family Plus
# **Policy Number:** RSAHLIP22200V032122
# **Plan Type:** Family Floater Policy
# **Eligibility Criteria:**
# *   **Adults:** 18 years onwards.
# *   **Children:** 91 days to 21 years.
# *   **New Born Baby:** 1 day to 90 days, can be added to existing policies at renewal.
# *   **Maternity Benefit:** Available for Insured Person covered with at least one adult Insured person at inception under the same Family Floater Policy.
# *   **Health Check-up/Second Opinion for Critical Illness:** Available for Insured Persons aged 18 years or above (Second Opinion not available to policyholder’s child).
# ...

# %%
import os
import fitz  # PyMuPDF
import google.generativeai as genai
from google.colab import userdata # Import userdata

# === STEP 1: Set up your Gemini API Key securely ===
# os.environ["GOOGLE_API_KEY"] = "AIzaSyD2eTdgrEiLn6XKgPwfOOaB0uLX7OJVFd0".strip()  # Replace with your actual API key
# genai.configure(api_key=os.getenv("GOOGLE_API_KEY").strip())

# Set your Gemini API Key
os.environ["GOOGLE_API_KEY"] = "AIzaSyA8jvipHq3awtK-Uh2cB1GGPonaUj7z1tc"
genai.configure(api_key=os.environ["GOOGLE_API_KEY"])
# Get the API key from Colab secrets
GOOGLE_API_KEY=userdata.get('GOOGLE_API_KEY')
genai.configure(api_key=GOOGLE_API_KEY)


# === STEP 2: Function to extract text from PDF ===
def extract_text_from_pdf(pdf_path):
    doc = fitz.open(pdf_path)
    full_text = ""
    for page in doc:
        full_text += page.get_text()
    doc.close()
    return full_text

# === STEP 3: Extract structured policy data using Gemini ===
def extract_policy_details_from_pdf(pdf_path):
    pdf_text = extract_text_from_pdf(pdf_path)

    prompt = f"""
You are an AI assistant working for a health insurance company.

From the text below, extract the following **policy-related details**:
- Policy Name
- Policy Number (if available)
- Type of Plan (e.g., Individual, Family, Corporate, Youth)
- Eligibility Criteria (age, conditions, etc.)
- Sum Insured options
- Premium details
- Coverage benefits (brief list)
- Major exclusions
- Policy term/duration
- Renewal terms
- Waiting period (if mentioned)

Return the result in this structured format:
Policy Name:
Policy Number:
Plan Type:
Eligibility Criteria:
Sum Insured:
Premium Details:
Coverage Benefits:
Exclusions:
Policy Term:
Renewal Terms:
Waiting Period:

Text to analyze:
\"\"\"{pdf_text}\"\"\"
"""

    model = genai.GenerativeModel("gemini-2.5-flash-preview-05-20")
    response = model.generate_content(prompt)
    return response.text

# === STEP 4: Run the extraction ===
pdf_path = "/content/Revised_Reliance_Health_Gain_Policy_Wordings.pdf"  # Replace with your actual PDF path
result = extract_policy_details_from_pdf(pdf_path)

# === STEP 5: Display result ===
print("=== Extracted Policy Details ===")
print(result)
# Out:
# === Extracted Policy Details ===
# Here are the policy-related details extracted from the provided text:
#
# **Policy Name:** Reliance Health Gain Policy
# **Policy Number:** RELHLIP22229V032122
# **Plan Type:** Individual and Family Floater plans with three tiers: Plus, Power, and Prime.
# **Eligibility Criteria:**
# *   **Insured Person(s):** Person(s) named in the Policy Schedule, meeting eligibility requirements and for whom premium is received.
# *   **Child:** Biological or legally adopted son or daughter, aged between 3 months to 25 years, financially dependent, and without an independent source of income.
# *   **Family (for Floater):** Policyholder, legally wedded spouse, parents and/or parents-in-law, and a maximum of six dependent children (3 months to 25 years).
# *   **Senior Citizen:** Person who has completed 60 or more years of age at the date of commencement or renewal of the Policy (relevant for co-payment).
# **Sum Insured:**
# ...

# %%
import os
import fitz  # PyMuPDF
import google.generativeai as genai
from google.colab import userdata # Import userdata


# Set your Gemini API Key
os.environ["GOOGLE_API_KEY"] = "AIzaSyBdN4pcBy1MX_eFiE4jyfHxULdIjBHxcmM"
genai.configure(api_key=os.environ["GOOGLE_API_KEY"])
# Get the API key from Colab secrets
GOOGLE_API_KEY=userdata.get('GOOGLE_API_KEY')
genai.configure(api_key=GOOGLE_API_KEY)


# === STEP 2: Function to extract text from PDF ===
def extract_text_from_pdf(pdf_path):
    doc = fitz.open(pdf_path)
    full_text = ""
    for page in doc:
        full_text += page.get_text()
    doc.close()
    return full_text

# === STEP 3: Extract structured policy data using Gemini ===
def extract_policy_details_from_pdf(pdf_path):
    pdf_text = extract_text_from_pdf(pdf_path)

    prompt = f"""
You are an AI assistant working for a health insurance company.

From the text below, extract the following **policy-related details**:
- Policy Name
- Policy Number (if available)
- Type of Plan (e.g., Individual, Family, Corporate, Youth)
- Eligibility Criteria (age, conditions, etc.)
- Sum Insured options
- Premium details
- Coverage benefits (brief list)
- Major exclusions
- Policy term/duration
- Renewal terms
- Waiting period (if mentioned)

Return the result in this structured format:
Policy Name:
Policy Number:
Plan Type:
Eligibility Criteria:
Sum Insured:
Premium Details:
Coverage Benefits:
Exclusions:
Policy Term:
Renewal Terms:
Waiting Period:

Text to analyze:
\"\"\"{pdf_text}\"\"\"
"""

    model = genai.GenerativeModel("gemini-2.5-flash-preview-05-20")
    response = model.generate_content(prompt)
    return response.text

# === STEP 4: Run the extraction ===
pdf_path = "/content/Health Pulse - Policy Wordings.pdf"  # Replace with your actual PDF path
result = extract_policy_details_from_pdf(pdf_path)

# === STEP 5: Display result ===
print("=== Extracted Policy Details ===")
print(result)
# Out:
# === Extracted Policy Details ===
# Policy Name: Health Pulse
# Policy Number: NBHHLIP22155V032122
# Plan Type: Individual, Family Floater
#
# Eligibility Criteria:
# *   **Individual Policy**: Single individual named in the Policy Schedule.
# *   **Family Floater Policy**: Covers the Primary Insured Person, their legally married spouse, and up to 4 children who are less than 25 years of age at the commencement of the policy period.
# *   Children completing 26 years of age will need to take a separate policy upon renewal.
#
# Sum Insured:
# *   **Base Sum Insured Options**: INR 3 Lacs, 4 Lacs, 5 Lacs, 7.5 Lacs, 10 Lacs, 15 Lacs, 20 Lacs, 25 Lacs.
# *   **No Claim Bonus (NCB)**: Increases Base Sum Insured by 10% per claim-free year, up to a maximum of 100% of Base Sum Insured (or 20% increase up to 200% with Enhanced No Claim Bonus optional benefit).
# ...

# %%
import os
import fitz  # PyMuPDF
import google.generativeai as genai
from google.colab import userdata # Import userdata


# Set your Gemini API Key
os.environ["GOOGLE_API_KEY"] = "AIzaSyBdN4pcBy1MX_eFiE4jyfHxULdIjBHxcmM"
genai.configure(api_key=os.environ["GOOGLE_API_KEY"])
# Get the API key from Colab secrets
GOOGLE_API_KEY=userdata.get('GOOGLE_API_KEY')
genai.configure(api_key=GOOGLE_API_KEY)


# === STEP 2: Function to extract text from PDF ===
def extract_text_from_pdf(pdf_path):
    doc = fitz.open(pdf_path)
    full_text = ""
    for page in doc:
        full_text += page.get_text()
    doc.close()
    return full_text

# === STEP 3: Extract structured policy data using Gemini ===
def extract_policy_details_from_pdf(pdf_path):
    pdf_text = extract_text_from_pdf(pdf_path)

    prompt = f"""
You are an AI assistant working for a health insurance company.

From the text below, extract the following **policy-related details**:
- Policy Name
- Policy Number (if available)
- Type of Plan (e.g., Individual, Family, Corporate, Youth)
- Eligibility Criteria (age, conditions, etc.)
- Sum Insured options
- Premium details
- Coverage benefits (brief list)
- Major exclusions
- Policy term/duration
- Renewal terms
- Waiting period (if mentioned)

Return the result in this structured format:
Policy Name:
Policy Number:
Plan Type:
Eligibility Criteria:
Sum Insured:
Premium Details:
Coverage Benefits:
Exclusions:
Policy Term:
Renewal Terms:
Waiting Period:

Text to analyze:
\"\"\"{pdf_text}\"\"\"
"""

    model = genai.GenerativeModel("gemini-2.5-flash-preview-05-20")
    response = model.generate_content(prompt)
    return response.text

# === STEP 4: Run the extraction ===
pdf_path = "/content/My-Health-Care-Plan1-PW.pdf"  # Replace with your actual PDF path
result = extract_policy_details_from_pdf(pdf_path)

# === STEP 5: Display result ===
print("=== Extracted Policy Details ===")
print(result)
# Out:
# === Extracted Policy Details ===
# Here are the policy-related details extracted from the text:
#
# **Policy Name:** My Health Care Plan (Plan 1)
# **Policy Number:** BAJHLIP23143V012223 (UIN provided, which is a unique identification number for the product)
# **Plan Type:**
# *   **Individual Policy:** Covers Insured, lawfully wedded spouse, dependent children, dependent parents, dependent siblings, dependent parents-in-law, dependent aunts/uncles, dependent grandchildren.
# *   **Family Floater Policy:** Covers Insured, lawfully wedded spouse, and dependent children. Separate floater policy can be taken for Parents/Parents-in-law.
#
# **Eligibility Criteria:**
# *   **Age:** Insured or family members must be between 3 months and 65 years of age at the commencement of the Policy Period.
# *   **Maternity Coverage:** Applicable for Insured Beneficiary up to 45 years of age.
# *   **Wellness Discount:** Applicable for members aged 25 years and above.
# ...

# %%
import os
import fitz  # PyMuPDF
import google.generativeai as genai
from google.colab import userdata # Import userdata


# Set your Gemini API Key
os.environ["GOOGLE_API_KEY"] = "AIzaSyBdN4pcBy1MX_eFiE4jyfHxULdIjBHxcmM"
genai.configure(api_key=os.environ["GOOGLE_API_KEY"])
# Get the API key from Colab secrets
GOOGLE_API_KEY=userdata.get('GOOGLE_API_KEY')
genai.configure(api_key=GOOGLE_API_KEY)


# === STEP 2: Function to extract text from PDF ===
def extract_text_from_pdf(pdf_path):
    doc = fitz.open(pdf_path)
    full_text = ""
    for page in doc:
        full_text += page.get_text()
    doc.close()
    return full_text

# === STEP 3: Extract structured policy data using Gemini ===
def extract_policy_details_from_pdf(pdf_path):
    pdf_text = extract_text_from_pdf(pdf_path)

    prompt = f"""
You are an AI assistant working for a health insurance company.

From the text below, extract the following **policy-related details**:
- Policy Name
- Policy Number (if available)
- Type of Plan (e.g., Individual, Family, Corporate, Youth)
- Eligibility Criteria (age, conditions, etc.)
- Sum Insured options
- Premium details
- Coverage benefits (brief list)
- Major exclusions
- Policy term/duration
- Renewal terms
- Waiting period (if mentioned)

Return the result in this structured format:
Policy Name:
Policy Number:
Plan Type:
Eligibility Criteria:
Sum Insured:
Premium Details:
Coverage Benefits:
Exclusions:
Policy Term:
Renewal Terms:
Waiting Period:

Text to analyze:
\"\"\"{pdf_text}\"\"\"
"""

    model = genai.GenerativeModel("gemini-2.5-flash-preview-05-20")
    response = model.generate_content(prompt)
    return response.text

# === STEP 4: Run the extraction ===
pdf_path = "/content/Senior-Citizens-Red-Carpet-Health-InsurancePolicy (1).pdf"  # Replace with your actual PDF path
result = extract_policy_details_from_pdf(pdf_path)

# === STEP 5: Display result ===
print("=== Extracted Policy Details ===")
print(result)
# Out:
# === Extracted Policy Details ===
# Here are the policy-related details extracted from the text:
#
# **Policy Name:** Senior Citizens Red Carpet Health Insurance Policy
# **Policy Number:** POL / SCRC / V.19 / 2024
# **Plan Type:** For Senior Citizens, available on Individual or Floater (Self and Spouse) basis.
# **Eligibility Criteria:** Designed for Senior Citizens (specific age range not provided in the text).
# **Sum Insured:** Options available from Rs. 1,00,000/- to Rs. 25,00,000/-.
# **Premium Details:**
# *   Premium can be paid in Half Yearly, Quarterly, or Monthly installments.
# *   No loading applies on renewals based on individual claims experience.
# **Coverage Benefits:**
# ...

# %%
import os
import fitz  # PyMuPDF
import google.generativeai as genai
from google.colab import userdata # Import userdata


# Set your Gemini API Key
os.environ["GOOGLE_API_KEY"] = "AIzaSyBdN4pcBy1MX_eFiE4jyfHxULdIjBHxcmM"
genai.configure(api_key=os.environ["GOOGLE_API_KEY"])
# Get the API key from Colab secrets
GOOGLE_API_KEY=userdata.get('GOOGLE_API_KEY')
genai.configure(api_key=GOOGLE_API_KEY)


# === STEP 2: Function to extract text from PDF ===
def extract_text_from_pdf(pdf_path):
    doc = fitz.open(pdf_path)
    full_text = ""
    for page in doc:
        full_text += page.get_text()
    doc.close()
    return full_text

# === STEP 3: Extract structured policy data using Gemini ===
def extract_policy_details_from_pdf(pdf_path):
    pdf_text = extract_text_from_pdf(pdf_path)

    prompt = f"""
You are an AI assistant working for a health insurance company.

From the text below, extract the following **policy-related details**:
- Policy Name
- Policy Number (if available)
- Type of Plan (e.g., Individual, Family, Corporate, Youth)
- Eligibility Criteria (age, conditions, etc.)
- Sum Insured options
- Premium details
- Coverage benefits (brief list)
- Major exclusions
- Policy term/duration
- Renewal terms
- Waiting period (if mentioned)

Return the result in this structured format:
Policy Name:
Policy Number:
Plan Type:
Eligibility Criteria:
Sum Insured:
Premium Details:
Coverage Benefits:
Exclusions:
Policy Term:
Renewal Terms:
Waiting Period:

Text to analyze:
\"\"\"{pdf_text}\"\"\"
"""

    model = genai.GenerativeModel("gemini-2.5-flash-preview-05-20")
    response = model.generate_content(prompt)
    return response.text

# === STEP 4: Run the extraction ===
pdf_path = "/content/myhealth-women-suraksha.pdf"  # Replace with your actual PDF path
result = extract_policy_details_from_pdf(pdf_path)

# === STEP 5: Display result ===
print("=== Extracted Policy Details ===")
print(result)
# Out:
# === Extracted Policy Details ===
# Here are the policy-related details extracted from the provided text:
#
# **Policy Name:** my:health Women Suraksha
# **Policy Number:** UIN - HDFHLIP22142V032122
# **Plan Type:** Individual (focused on women, can cover multiple insured persons, but discounts apply to individual renewal premiums)
# **Eligibility Criteria:**
# *   Insured Person(s) must be above 18 years of age.
# *   For the optional "Pregnancy and Newborn Complications" cover, the maximum effective age is 50 years.
# **Sum Insured:**
# The policy provides cover up to the Sum Insured or limits mentioned in the Policy Schedule. Specific benefit payouts are either 100% of Sum Insured or 25% of Sum Insured (subject to a maximum of Rs. 1,000,000 for certain minor conditions and surgical procedures).
# Available Sum Insured options (implied by health check-up tiers):
# *   Rs. 1 Lac to Rs. 10 Lacs
# *   Rs. 11 Lacs to Rs. 50 Lacs
# *   Above Rs. 50 Lacs
# **Premium Details:**
# ...
